# %% [markdown]
# <a href="https://colab.research.google.com/github/AntonioDJSS/ImagenesDigitales/blob/main/Objetos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow
import cv2


def run():
  original = cv2.imread('/content/konosubarashi.jpg')
  cv2_imshow(original)
  gris = cv2.cvtColor(original, cv2.COLOR_BGR2GRAY)
  gauss = cv2.GaussianBlur(gris,(5, 5), 0)
  cv2_imshow(gauss)
  canny = cv2.Canny(gauss, 50, 150)
  cv2_imshow(canny)
  (contornos,_) = cv2.findContours(canny.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
  print(f'He encontrado {len(contornos)}')
  cv2.drawContours(original,contornos, -1,(0,0,255), 2)
  cv2_imshow(original)
  cv2.waitKey(0)


if __name__ == '__main__':
  run()
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7FD086B23B10>
# <PIL.Image.Image image mode=L size=1280x720 at 0x7FD086B8DF90>
# <PIL.Image.Image image mode=L size=1280x720 at 0x7FD087BE45D0>
# He encontrado 247
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7FD0974AB2D0>
