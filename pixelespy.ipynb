# %% [markdown]
# <a href="https://colab.research.google.com/github/AntonioDJSS/ImagenesDigitales/blob/main/pixelespy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from skimage import io
imagen = io.imread("/content/rgb-cmyk.png")
io.imshow(imagen)
imagen.shape
# Out:
# (676, 772, 4)

# %%
from skimage import io
import pandas as pd

image = io.imread('/content/rgb-cmyk.png')
df = pd.DataFrame(imagen.flatten())

df.to_csv('/content/coordenadas.csv')

io.imshow(imagen)
image.shape
# Out:
# (676, 772, 4)

# %%
import numpy as np
from skimage import io

bgr = np.zeros((1,1,3), dtype=np.uint8)
print('Escala de grises')
io.imshow(bgr, cmap = "gray")
# Out:
# Escala de grises

# %%
import numpy
from skimage import io
size = (5,5)

imagen_aleatoria= np.random.rand(size[0], size[1])
io.imshow(imagen_aleatoria)
